# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#reserviors = pd.read_csv(r'development-byreservoir.csv')
reserviors = pd.read_csv(r'development-byreservoir-trimmed.csv')
reserviors
# Out:
#             Reservior       State  Installed_MWe  FirstGen
# 0              Amedee  California          1.600      1988
# 1             Beowawe      Nevada         19.900      1985
# 2       Blue Mountain      Nevada         49.500      2009
# 3              Bradys      Nevada         26.100      1992
# 4           Cove Fort        Utah         25.000      2013
# 5         Desert Peak      Nevada         23.000      1985
# 6        Dixie Valley      Nevada         72.000      1988
# 7        Don Campbell      Nevada         42.000      2013
# 8      Florida Canyon      Nevada          0.075      2012
# 9         Goodsprings      Nevada          7.000      2010
# 10  Hammersley Canyon      Oregon          2.100      1984
# 11      Jersey Valley      Nevada         22.500      2010
# 12      Klamath Falls      Oregon          2.030      2010
# 13    Lightening Dock  New Mexico          4.000      2013
# 14    McGinness Hills      Nevada        143.000      2012
# 15   Neal Hot Springs      Oregon         30.100      2012
# 16            Paisley      Oregon          3.000      2014
# 17              Patua      Nevada         30.000      2013
# 18         Raft River       Idaho         15.800      2008
# 19     Rockford Ranch      Oregon          0.040      1982
# 20          Roosevelt        Utah         36.000      1984
# 21         Salt Wells      Nevada         23.600      2009
# 22         San Emidio      Nevada         15.400      1987
# 23          Soda Lake      Nevada         23.100      1987
# 24         Stillwater      Nevada         47.300      2009
# 25             Thermo        Utah         10.300      2009
# 26           Tungsten      Nevada         24.000      2017
# 27           Tuscaroa      Nevada         18.000      2012
# 28            Wabuska      Nevada          2.200      1984
# 29             Wendel  California          0.700      1985

# %%
plt.figure(
    figsize=(12,5),
    constrained_layout=True,
)

sortedbymw = reserviors.sort_values(
    by = 'Installed_MWe',
    ascending=False
)

sns.barplot(
    x = 'Reservior',     
    y = 'Installed_MWe', 
    data = sortedbymw,
    color = '#cccccc'
) 

plt.title('Installed capacity (MWe) for reservoirs in the US Basin and Range province, excluding the Walker Lane and Mammoth Mountain')

plt.xticks(rotation=90)
plt.xlabel('')
plt.ylabel('Installed MWe')

plt.savefig('MWe-Per-Reservoir.png',dpi=400,bbox_inches='tight')
plt.show()

# %%
plt.figure(
    figsize=(12,4),
    constrained_layout=True,
)

sns.distplot(
    reserviors.Installed_MWe,
    bins = 80, # change this value to view the underlying distribution in different ways
    color = '#7a7a7a',
) 

plt.vlines(3.5,0,0.08,linestyle='-.',alpha=0.3,label='25% 3.5 MWe')
plt.vlines(22.5,0,0.08,linestyle='--',alpha=0.3,label='median 50% 22 MWe')
plt.vlines(30,0,0.08,linestyle='-.',alpha=0.3,label='75% 30 MWe')

plt.vlines(27,0,0.08,linestyle=':',alpha=0.6,label='mean 28 MWe')

plt.title('Histogram with probability density function (kernel density estimation method) of installed capacity (MWe)')

plt.xlabel('Installed capacity [MWe] -- reservoirs in the Basin and Range, excluding the Walker Lane and Mammoth Mountain')

plt.ylim(0,0.08)

plt.legend()

plt.savefig('MWe-Per-Reservoir-PDF.png',dpi=400,bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plants = pd.read_csv(r'development-byplant.csv')
plants
# Out:
#             Reservior                                     Name  Comissioned  \
# 0              Amedee                                   Amedee         1988
# 1             Beowawe                                  Beowawe         1985
# 2             Beowawe                                Beowawe 2         2011
# 3       Blue Mountain                   Blue Mountain Faulkner         2009
# 4              Bradys                        Brady Hot Springs         1992
# 5                Coso   Coso Finance Partners Geothermal Plant         1987
# 6                Coso  Coso Energy Developers Geothermal Plant         1988
# 7                Coso   Coso Power Developers Geothermal Plant         1989
# 8           Cove Fort                                Cove Fort         2013
# 9         Desert Peak             Desert Peak (decommissioned)         1985
# 10        Desert Peak                              Desert Peak         2006
# 11       Dixie Valley                             Dixie Valley         1988
# 12       Dixie Valley                           Dixie Valley 2         2012
# 13       Don Campbell                           Don Campbell 1         2013
# 14       Don Campbell                           Don Campbell 2         2015
# 15     Florida Canyon                      Florida Canyon Mine         2012
# 16        Goodsprings                              Goodsprings         2010
# 17  Hammersley Canyon                        Hammersley Canyon         1984
# 18      Jersey Valley                            Jersey Valley         2010
# 19      Klamath Falls                          Klamath Falls 1         2010
# 20      Klamath Falls                          Klamath Falls 2         2014
# 21    Lightening Dock                          Lightening Dock         2013
# 22            Mammoth                            Casa Diablo 1         1984
# 23            Mammoth                            Casa Diablo 2         1990
# 24            Mammoth                            Casa Diablo 3         1990
# 25    McGinness Hills                        McGinness Hills 1         2012
# 26    McGinness Hills                        McGinness Hills 2         2015
# 27    McGinness Hills                        McGinness Hills 3         2018
# 28   Neal Hot Springs                         Neal Hot Springs         2012
# 29            Paisley                                  Paisley         2014
# 30             Patua                                     Patua         2013
# 31         Raft River                               Raft River         2008
# 32     Rockford Ranch                           Rockford Ranch         1982
# 33          Roosevelt          Blundell Geothermal Power Plant         1984
# 34          Roosevelt                          Blundell Unit 2         2007
# 35         Salt Wells                               Salt Wells         2009
# 36         San Emidio                      San Emidio (Empire)         1987
# 37         San Emidio                       San Emidio Repower         2012
# 38          Soda Lake                                Soda Lake         1987
# 39          Soda Lake                             Soda Lake II         1991
# 40          Steamboat                              Steamboat 1         1986
# 41          Steamboat                             Steamboat 1A         1988
# 42          Steamboat                         Steamboat Hills          1988
# 43          Steamboat                              Steamboat 2         1992
# 44          Steamboat                              Steamboat 3         1992
# 45          Steamboat               Richard Burdett (Galena I)         2005
# 46          Steamboat                                Galena II         2007
# 47          Steamboat                               Galena III         2008
# 48         Stillwater                               Stillwater         2009
# 49             Thermo                                   Thermo         2009
# 50           Tungsten                                 Tungsten         2017
# 51           Tuscaroa                               Tuscaroa 1         2012
# 52            Wabuska                                Wabuska 1         1984
# 53            Wabuska                                Wabuska 2         1987
# 54            Wabuska                         Wabuska 3 (plus)         2003
# 55             Wendel                                   Wendel         1985
#
#             Type  Capacity_Mwe  NetGen_Mwe               Status  \
# 0         binary          1.60         NaN                  NaN
# 1   double flash         18.00         NaN                  NaN
# 2         binary          1.90         NaN                  NaN
# 3         binary         50.00         NaN                  NaN
# 4   double flash         26.10         NaN                  NaN
# 5          flash         90.20         NaN                  NaN
# 6          flash         90.00         NaN                  NaN
# 7          flash         90.00         NaN                  NaN
# 8         binary         25.00         NaN                  NaN
# 9          flash          9.90         NaN  decommissioned 1985
# 10        binary         11.00         NaN                  NaN
# 11  double flash         64.00         NaN                  NaN
# 12        binary          6.20         NaN            operating
# 13        binary         26.00         NaN            operating
# 14        binary         16.00         NaN            operating
# 15        binary          0.10         NaN            operating
# 16        binary          7.00         NaN                  NaN
# 17        binary          2.10         NaN               failed
# 18        binary         22.50         NaN                  NaN
# 19        binary          0.28         NaN                  NaN
# 20        binary          1.75         NaN                  NaN
# 21        binary          4.00         NaN                  NaN
# 22        binary         10.00         NaN                  NaN
# 23        binary         10.00         NaN                  NaN
# 24        binary         10.00         NaN                  NaN
# 25        binary         45.00         NaN                  NaN
# 26        binary         45.00         NaN                  NaN
# 27        binary         48.00         NaN                  NaN
# 28        binary         33.00        22.0                  NaN
# 29        binary          3.00         NaN                  NaN
# 30        binary         30.00        15.0                  NaN
# 31        binary         15.80         NaN                  NaN
# 32        binary          0.04         NaN                  NaN
# 33         flash         26.00         NaN                  NaN
# 34        binary         11.00         NaN                  NaN
# 35        binary         23.60        20.2                  NaN
# 36        binary          3.60         NaN                  NaN
# 37        binary         11.80         NaN                  NaN
# 38        binary          5.10         NaN                  NaN
# 39        binary         18.00         NaN                  NaN
# 40        binary          8.40         NaN                  NaN
# 41        binary          2.40         NaN                  NaN
# 42        binary         14.60         NaN                  NaN
# 43        binary         13.40         NaN                  NaN
# 44        binary         13.40         NaN                  NaN
# 45        binary         26.00         NaN            Operating
# 46        binary         13.00         NaN                  NaN
# 47        binary         26.50         NaN                  NaN
# 48        binary         47.30         NaN                  NaN
# 49        binary         10.30         NaN                  NaN
# 50        binary         24.00         NaN                  NaN
# 51        binary         18.00         NaN                  NaN
# 52        binary          0.80         NaN                  NaN
# 53        binary          0.80         NaN                  NaN
# 54        binary          4.00         NaN                  NaN
# 55        binary          0.70         NaN                  NaN
#
#                                             Owner
# 0                                             NaN
# 1                               Beowawe Power LLC
# 2                                 Terra-Gen Power
# 3                                        Altarock
# 4                                           Ormat
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8         ENEL Green Power (Oski Energy phase 2?)
# 9                                         Unknown
# 10                                          Ormat
# 11                        Terra-Gen Operating Co.
# 12                                Terra-Gen Power
# 13                                          Ormat
# 14                                          Ormat
# 15                                   ElectraTherm
# 16                                      NV Energy
# 17                                        Unknown
# 18                                          Ormat
# 19                 Oregon Institute of Technology
# 20                 Oregon Institute of Technology
# 21                                        Unknown
# 22                                          Ormat
# 23                                          Ormat
# 24                                          Ormat
# 25                                          Ormat
# 26                                          Ormat
# 27                                          Ormat
# 28                           U.S. Geothermal Inc.
# 29                   Surprise Valley Eletric Corp
# 30                                           Cyrq
# 31                           U.S. Geothermal Inc.
# 32                                        Unknown
# 33                                   Pacific Corp
# 34                                   Pacific Corp
# 35                               Enel Green Power
# 36                                U.S. Geothermal
# 37                                U.S. Geothermal
# 38                                           Cyrq
# 39                                           Cyrq
# 40                                          Ormat
# 41                                          Ormat
# 42                                          Ormat
# 43                                          Ormat
# 44                                          Ormat
# 45                                          Ormat
# 46                                          Ormat
# 47                                          Ormat
# 48                                        Enel NA
# 49                                           Cirq
# 50                                          Ormat
# 51                                          Ormat
# 52  Homestretch Geothermal / Sierra Pacific Power
# 53  Homestretch Geothermal / Sierra Pacific Power
# 54  Homestretch Geothermal / Sierra Pacific Power
# 55                                        Unknown

# %%
plt.figure(
    figsize=(14,8),
    constrained_layout=True,
)

sortedbymw = plants.sort_values(
    by = 'Capacity_Mwe',
    ascending=False
)

sns.barplot(
    x = 'Name',     
    y = 'Capacity_Mwe', 
    data = sortedbymw,
    color = '#cccccc'
) 

plt.title('Power plant capacity (MWe) in the US Basin and Range province')

plt.xticks(rotation=90)
plt.xlabel('')
plt.ylabel('Installed MWe')

plt.show()

# %%
sortedbymw = plants.sort_values(
    by = 'Capacity_Mwe',
    ascending=False
)

x = sortedbymw.Name
y = sortedbymw.Capacity_Mwe

planttype = sortedbymw.Type
col = []
for val in planttype:
    if val == 'binary':
        col.append('#cccccc')
    elif val == 'flash':
        col.append('#7a7a7a')
    else:
        col.append('#7a7a7a')

plt.figure(
    figsize=(14,7),
    constrained_layout=True,
)

plt.bar(x,y, color = col)

plt.title('Power plant capacity (MWe) in the US Basin and Range province (flash = dark grey, binary = light grey)')

plt.xticks(rotation=90)
plt.xlabel('')
plt.ylabel('Installed MWe')

plt.show()

# %% [markdown]
# ### Ayling, B. F., 2020, 35 years of geothermal power generation in Nevada, USA: A review of field development, generation, and production histories Proceedings, 45th Workshop on Geothermal Reservoir Engineering: Stanford, CA. https://www.geothermal-energy.org/explore/our-databases/conference-paper-database/
